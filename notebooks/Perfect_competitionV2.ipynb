# %% [markdown]
# # Perfect competition

# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline
import numpy as np
import random
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# import all of our files
import sys
sys.path.append('../')

import fico
import support_functions as sf
#main model classses
from market import Market
from bank import Bank
from applicant_group import Applicant_group

DATA_DIR = '../data/'

# set plotting parameters
sns.set_context("talk")
sns.set_style("white")

# this needs to be here so we can edit figures later
plt.rcParams['pdf.fonttype'] = 42
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Variables

# %%
### Simulation settings ###
time_steps = 100

### Market setting ###
score_range = [300,850]
repay_score = 75
default_score = -150

#this correspends to selection rate(perfect competition [0,1])
plane_range = [0, 1]
plane_slice_step = 0.01

#initial interest rate setting
initial_interest_rate_range = [0.15, 0.1]

#demand and supply interest rate boundaries
max_interest_rate_range = [0.3, 0.2]
min_interest_rate_range = [0.03, 0.02]

#policy
selected_policy = 0  #0=MU, 1=DP , 2=EO 
policy_names = ["Max. utility", "Dem. parity", "Equal opportunity" ]
policy_colors = ['green', 'blue', 'red']

### Bank setting ###
bank_line_style = ['-.']
bank_color = ['blue']
#number of banks in the market
N_banks = 21

#bank score distribution shift(same number of shifts as banks)
score_shifts = [0, -5, -10, -15, -20, -25, -30, -35, -40, -45, -50, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50]

# profit and impact for banks (same for every bank, but different profit and impact can be set for each bank and model different revenue/cost "function")
utility_repaid = 1
utility_default = -4

### Applicant groups setting ###
#use unique names
group_names = ["White","Black"]
group_colors = ['grey', 'black']
group_line_style = ['-',':']

#maximal interest rate which are applicants willing to accept
interest_rate_limit = 0.3

#estimated number of applicants in each group
white_totals = 8800
black_totals = 1200
loan_demand = 0.1

error_rate = 0.5
score_error_black = 150
score_error_white = -150

# %% [markdown]
# # Prepare initial data

# %%
all_cdfs, performance, totals = fico.get_FICO_data(data_dir=DATA_DIR);
cdfs = all_cdfs[group_names]
cdf_groups = np.transpose(cdfs.values)

scores = cdfs.index
scores_list = scores.tolist()
scores_repay = cdfs.index

repays = performance[group_names]

totals = fico.read_totals(data_dir=DATA_DIR)
##### comment to use dataset totals (but there are too many people and the simulation will be slow)
totals['White'] = white_totals
totals['Black'] = black_totals
####
group_totals = np.zeros(len(group_names), dtype=np.int32)
for i in range(0,len(group_names)):
    group_totals[i] = int(totals[group_names[i]])

pis = np.zeros(cdf_groups.shape)
applicant_totals = np.zeros(len(group_names), dtype=np.int32)

for i in range(0, len(group_names)): 
    pis[i] = sf.get_pmf(cdf_groups[i])
    applicant_totals[i] = np.sum(np.round(pis[i]*group_totals[i]))
print("Reference group totals: " + str(group_totals))
print("Calculated group totals: " + str(applicant_totals))

#demographic statistics 
group_ratio = np.array((applicant_totals[0], applicant_totals[1]))
group_size_ratio = group_ratio/group_ratio.sum()
print("Group size ratio: " + str(group_size_ratio))

pis_total = np.round(pis*group_totals[:, None])

ref_applicant_scores = sf.get_ref_applicants(applicant_totals, pis_total, scores_list)
# Out:
# Reference group totals: [8800 1200]
# Calculated group totals: [8805 1193]
# Group size ratio: [0.88067614 0.11932386]
# ../fico.py:63: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   cdfs = cleanup_frame(pd.DataFrame.from_csv(data_dir + filenames[0]))
# ../fico.py:64: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   performance = 100 - cleanup_frame(pd.DataFrame.from_csv(data_dir + filenames[1]))
# ../fico.py:28: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   frame = cleanup_frame(pd.DataFrame.from_csv(data_dir + FILES['overview']))

# %% [markdown]
# # Create Model

# %%
#create market
market = Market(policy_names[selected_policy], policy_colors[selected_policy], score_range = score_range ,repay_score = repay_score, default_score = default_score, max_interest_rate_range = max_interest_rate_range, min_interest_rate_range = min_interest_rate_range, plane_range=plane_range, plane_slice_step = plane_slice_step)

banks= []
for i in range(0,N_banks):
    banks.append(Bank("bank_%02d" % i, bank_color[0],bank_line_style[0], initial_interest_rate_range, market, score_shift=score_shifts[i], utility_repaid=utility_repaid, utility_default = utility_default))

white_group = Applicant_group(group_names[0], group_colors[0], group_line_style[0], applicant_totals[0], ref_applicant_scores[0], loan_demand, error_rate, score_error_white, market, repays, ir_limit=interest_rate_limit)
black_group = Applicant_group(group_names[1], group_colors[1], group_line_style[1], applicant_totals[1], ref_applicant_scores[1], loan_demand, error_rate, score_error_black, market, repays, ir_limit=interest_rate_limit)
groups = [white_group, black_group]

# %% [markdown]
# ### Init model values

# %%
for bank in banks:
    market.max_irates[bank.name] = []
    market.min_irates[bank.name] = []
    market.max_irates[bank.name].append(bank.interest_rate_range[0])
    market.min_irates[bank.name].append(bank.interest_rate_range[1])
    
    for group in groups:
        bank.N_loan_curves[group.name] = []
        bank.total_utility_curves[group.name] = []

group_mean_score_change_curve = {}
total_loans = {}
total_utility = {}
for group in groups:      
    group_mean_score_change_curve[group.name] = [0]
    market.loans[group.name] = [0]
    market.utility[group.name] = [0]
    total_loans[group.name] = 0
    total_utility[group.name] = 0

# %% [markdown]
# # Next step

# %%
for time in range(0, time_steps):
    print("############### STEP "+ str(market.step) + " -> " + str(market.step+1) + " ##################" )
    utilities = {}
    utility_curves = {}
    N_loans = {}
    step_loans = 0
    step_applicants = 0
    
    ### Before ###            
    selection_rates, max_util = market.get_selection_rate(banks, groups)
    for bank in banks:
        bank.set_selection_rate(selection_rates[bank.name])
        utilities[bank.name] = {}
        utility_curves[bank.name] = {}
        N_loans[bank.name] = {}

    ### During ###
    for group in groups:
        for bank in banks:
            utilities[bank.name][group.name] = 0
            utility_curves[bank.name][group.name] = []
            N_loans[bank.name][group.name] = 0
            
        #select part of applicant base at random according to group loan demand
        applicants = np.sort(random.sample(range(0, group.size), int(group.size*group.loan_demand)))
        step_applicants += len(applicants) 
        #go over all selected applicants in the group
        for j in applicants:
            selected_bank = None
            bank_select_order = random.sample(range(0, len(banks)), len(banks))
            
            # check banks at random if they give loan to applicant j
            for k in bank_select_order:
                if j/group.size <= banks[k].group_selection_rate[group.name]:
                    selected_bank = k
                    step_loans += 1
                    total_loans[group.name] += 1
                    break

            if selected_bank is not None:
                #get loan outcome and change score
                N_loans[banks[selected_bank].name][group.name] += 1 
                loan_outcome = group.applicants[j].get_repay_outcome(market)
                expected_applicant_score = banks[selected_bank].get_expected_applicant_score(market, group.applicants[j].score)
                
                #get bank utility
                interest_rate = banks[selected_bank].score_interest_rates[group.applicants[j].score]
                utility_change = banks[selected_bank].get_applicant_utility(interest_rate, loan_outcome)
                utilities[banks[selected_bank].name][group.name] += utility_change
                total_utility[group.name] += utility_change
                utility_curves[banks[selected_bank].name][group.name].append(utilities[banks[selected_bank].name][group.name])
        
        for bank in banks:
            if market.step == 0:
                bank.N_loan_curves[group.name].append(N_loans[bank.name][group.name])
                bank.total_utility_curves[group.name].append(utilities[bank.name][group.name])
            else:
                bank.N_loan_curves[group.name].append(bank.N_loan_curves[group.name][-1] + N_loans[bank.name][group.name])
                bank.total_utility_curves[group.name].append(bank.total_utility_curves[group.name][-1] + utilities[bank.name][group.name])        
        group.sort_by_score()
        group_mean_score_change_curve[group.name].append(group.get_mean_score_change())
        print(group.name + " group mean score: " + str(group.get_mean_score_change()))
    
    market.step += 1 
    
    ### After ###
    #adjust interest rate, in perfect competition it depends on the total number of people who got a loan.
    total_selection_rate = str(round(step_loans/step_applicants,2))
    score_interest_rates = market.interest_rate_plane[total_selection_rate]
    
    for bank in banks:
        bank.change_interest_rate_range(score_interest_rates, market)
        
        market.max_irates[bank.name].append(score_interest_rates[market.score_range[0]])
        market.min_irates[bank.name].append(score_interest_rates[market.score_range[1]])
    
    for group in groups:
        market.loans[group.name].append(total_loans[group.name])
        market.utility[group.name].append(total_utility[group.name])
        print("Reference bank: " + group.name + " selection rate: " + str(banks[0].group_selection_rate[group.name]))
        
    print("Market selection rate: " + str(total_selection_rate),"Interest_rate:" + str(banks[0].interest_rate_range))
    
    market.plot_market_situation_PC(banks, groups, group_mean_score_change_curve)
# Out:
# ############### STEP 0 -> 1 ##################
# White group mean score: 0.5053946621237628
# Black group mean score: 1.0276613579212608
# Reference bank: White selection rate: 0.6752981260647359
# Reference bank: Black selection rate: 0.173512154233026
# Market selection rate: 0.68 Interest_rate:[0.1164, 0.0776]
# Loans - White: 657, Utility - White: -0.326482496194825
# Loans - Black: 27, Utility - Black: 0.5406666666666669
# Loans - Total: 684.0, Utility - Total: -0.2922529239766082
# ../market.py:354: RuntimeWarning: invalid value encountered in true_divide
#   ax[2][1].plot(list(range(len(self.utility[group.name]))), np.array(self.utility[group.name])/np.array(self.loans[group.name]), color = group.color, LineStyle = group.line_style,label = "Total utility per loan "+ group.name + " group")
# ../market.py:365: RuntimeWarning: invalid value encountered in true_divide
#   ax[2][1].plot(list(range(len(total_utility))), np.array(total_utility)/np.array(total_loans), color="red",label= "Total utility per loan")
# ############### STEP 1 -> 2 ##################
# White group mean score: 0.7936399772855793
# Black group mean score: 1.8533109807209485
# Reference bank: White selection rate: 0.6633730834752981
# Reference bank: Black selection rate: 0.17937971500419111
# Market selection rate: 0.69 Interest_rate:[0.1137, 0.0758]
# Loans - White: 1311, Utility - White: -0.34887086193745287
# Loans - Black: 60, Utility - Black: 0.33106033333333357
# Loans - Total: 1371.0, Utility - Total: -0.31911457330415804
#
# ############### STEP 2 -> 3 ##################
# White group mean score: 1.2382737081203459
# Black group mean score: 3.1634534786253425
# Reference bank: White selection rate: 0.6534923339011925
# Reference bank: Black selection rate: 0.18105616093880972
# Market selection rate: 0.68 Interest_rate:[0.1164, 0.0776]
# Loans - White: 1959, Utility - White: -0.3249919601837665
# Loans - Black: 91, Utility - Black: 0.4192738461538464
# Loans - Total: 2050.0, Utility - Total: -0.2919538195121945
#
# ############### STEP 3 -> 4 ##################
# White group mean score: 1.8086314593980433
# Black group mean score: 3.642078792958955
# Reference bank: White selection rate: 0.645542305508234
# Reference bank: Black selection rate: 0.18524727577535624
# Market selection rate: 0.66 Interest_rate:[0.1218, 0.0812]
# Loans - White: 2591, Utility - White: -0.2821118525665777
# Loans - Black: 121, Utility - Black: 0.2899723140495868
# Loans - Total: 2712.0, Utility - Total: -0.2565874483775822
#
# ############### STEP 4 -> 5 ##################
# White group mean score: 2.6839295854628062
# Black group mean score: 3.6965632858340314
# Reference bank: White selection rate: 0.6379329926178308
# Reference bank: Black selection rate: 0.19027661357921208
# Market selection rate: 0.67 Interest_rate:[0.1191, 0.0794]
# Loans - White: 3235, Utility - White: -0.23787625038640145
# Loans - Black: 150, Utility - Black: 0.13874606666666656
# Loans - Total: 3385.0, Utility - Total: -0.22118693057607344
#
# ############### STEP 5 -> 6 ##################
# White group mean score: 3.4651902328222377
# Black group mean score: 4.2682313495390645
# Reference bank: White selection rate: 0.6330494037478706
# Reference bank: Black selection rate: 0.18860016764459347
# Market selection rate: 0.66 Interest_rate:[0.1218, 0.0812]
# Loans - White: 3874, Utility - White: -0.19983654620547678
# Loans - Black: 170, Utility - Black: 0.16036582352941167
# Loans - Total: 4044.0, Utility - Total: -0.1846945079129617
#
# ############### STEP 6 -> 7 ##################
# White group mean score: 4.034639409426404
# Black group mean score: 5.747694886839895
# Reference bank: White selection rate: 0.625099375354912
# Reference bank: Black selection rate: 0.19279128248113997
# Market selection rate: 0.62 Interest_rate:[0.1326, 0.0884]
# Loans - White: 4462, Utility - White: -0.1787305558045774
# Loans - Black: 201, Utility - Black: 0.25268383084577106
# Loans - Total: 4663.0, Utility - Total: -0.1601343105297071
#
# ############### STEP 7 -> 8 ##################
# White group mean score: 4.5936399772856475
# Black group mean score: 6.802179379715085
# Reference bank: White selection rate: 0.6196479273140261
# Reference bank: Black selection rate: 0.1969823973176865
# Market selection rate: 0.63 Interest_rate:[0.1299, 0.0866]
# Loans - White: 5068, Utility - White: -0.14940126282557806
# Loans - Black: 225, Utility - Black: 0.31973537777777766
# Loans - Total: 5293.0, Utility - Total: -0.1294587455129472
#
# ############### STEP 8 -> 9 ##################
# White group mean score: 5.217717206132875
# Black group mean score: 7.953897736798012
# Reference bank: White selection rate: 0.6145371947756956
# Reference bank: Black selection rate: 0.20117351215423301
# Market selection rate: 0.63 Interest_rate:[0.1299, 0.0866]
# Loans - White: 5667, Utility - White: -0.12529903652726923
# Loans - Black: 255, Utility - Black: 0.37048650980392167
# Loans - Total: 5922.0, Utility - Total: -0.1039506214116911
#
# ############### STEP 9 -> 10 ##################
# White group mean score: 5.832254400908596
# Black group mean score: 8.413243922883566
# Reference bank: White selection rate: 0.6097671777399205
# Reference bank: Black selection rate: 0.20033528918692373
# Market selection rate: 0.61 Interest_rate:[0.1353, 0.0902]
# Loans - White: 6250, Utility - White: -0.09994981120000665
# Loans - Black: 283, Utility - Black: 0.3517957950530038
# Loans - Total: 6533.0, Utility - Total: -0.08038085259452647
#
# ############### STEP 10 -> 11 ##################
# White group mean score: 6.291879613855713
# Black group mean score: 9.181056160938851
# Reference bank: White selection rate: 0.6040885860306644
# Reference bank: Black selection rate: 0.20033528918692373
# Market selection rate: 0.6 Interest_rate:[0.138, 0.092]
# Loans - White: 6826, Utility - White: -0.07690786697920403
# Loans - Black: 306, Utility - Black: 0.3577789869281048
# Loans - Total: 7132.0, Utility - Total: -0.05825753365115628
#
# ############### STEP 11 -> 12 ##################
# White group mean score: 6.546394094264656
# Black group mean score: 10.300922045264088
# Reference bank: White selection rate: 0.599091425326519
# Reference bank: Black selection rate: 0.20201173512154233
# Market selection rate: 0.59 Interest_rate:[0.1407, 0.0938]
# Loans - White: 7383, Utility - White: -0.06648124204253703
# Loans - Black: 335, Utility - Black: 0.40660325373134365
# Loans - Total: 7718.0, Utility - Total: -0.04594699663125819
#
# ############### STEP 12 -> 13 ##################
# White group mean score: 6.65826235093698
# Black group mean score: 11.394803017602726
# Reference bank: White selection rate: 0.594434980124929
# Reference bank: Black selection rate: 0.20787929589270746
# Market selection rate: 0.61 Interest_rate:[0.1353, 0.0902]
# Loans - White: 7967, Utility - White: -0.05734097652818559
# Loans - Black: 364, Utility - Black: 0.44762065934065925
# Loans - Total: 8331.0, Utility - Total: -0.03527807466091161
#
# ############### STEP 13 -> 14 ##################
# White group mean score: 6.721749006246455
# Black group mean score: 12.283319362950579
# Reference bank: White selection rate: 0.5892106757524134
# Reference bank: Black selection rate: 0.20871751886001677
# Market selection rate: 0.61 Interest_rate:[0.1353, 0.0902]
# Loans - White: 8550, Utility - White: -0.047423465497083025
# Loans - Black: 387, Utility - Black: 0.47283049095607244
# Loans - Total: 8937.0, Utility - Total: -0.024894845026301876
#
# ############### STEP 14 -> 15 ##################
# White group mean score: 6.836910846110186
# Black group mean score: 13.6462699077955
# Reference bank: White selection rate: 0.5855763770584895
# Reference bank: Black selection rate: 0.21039396479463537
# Market selection rate: 0.58 Interest_rate:[0.1434, 0.0956]
# Loans - White: 9090, Utility - White: -0.03573079097910495
# Loans - Black: 422, Utility - Black: 0.500218909952607
# Loans - Total: 9512.0, Utility - Total: -0.011953375735919243
#
# ############### STEP 15 -> 16 ##################
# White group mean score: 7.062918796138547
# Black group mean score: 14.282481139983247
# Reference bank: White selection rate: 0.5827370812038615
# Reference bank: Black selection rate: 0.21207041072925398
# Market selection rate: 0.59 Interest_rate:[0.1407, 0.0938]
# Loans - White: 9654, Utility - White: -0.020706854153725442
# Loans - Black: 447, Utility - Black: 0.49949803131991066
# Loans - Total: 10101.0, Utility - Total: 0.0023137956637891938
#
# ############### STEP 16 -> 17 ##################
# White group mean score: 7.339125496876704
# Black group mean score: 15.145850796311834
# Reference bank: White selection rate: 0.5792163543441227
# Reference bank: Black selection rate: 0.21374685666387258
# Market selection rate: 0.56 Interest_rate:[0.1488, 0.0992]
# Loans - White: 10175, Utility - White: -0.006093826044232558
# Loans - Black: 481, Utility - Black: 0.5100190644490641
# Loans - Total: 10656.0, Utility - Total: 0.01720293637386764
#
# ############### STEP 17 -> 18 ##################
# White group mean score: 7.529585462805244
# Black group mean score: 15.945515507124924
# Reference bank: White selection rate: 0.5764906303236798
# Reference bank: Black selection rate: 0.21709974853310982
# Market selection rate: 0.56 Interest_rate:[0.1488, 0.0992]
# Loans - White: 10712, Utility - White: 0.008475922330090849
# Loans - Black: 506, Utility - Black: 0.5292154743083001
# Loans - Total: 11218.0, Utility - Total: 0.031964441968259316
# ############### STEP 18 -> 19 ##################
# White group mean score: 7.421010789324214
# Black group mean score: 17.044425817267438
# Reference bank: White selection rate: 0.573992049971607
# Reference bank: Black selection rate: 0.2179379715004191
# Market selection rate: 0.56 Interest_rate:[0.1488, 0.0992]
# Loans - White: 11246, Utility - White: 0.014558074871059182
# Loans - Black: 534, Utility - Black: 0.5592640636704114
# Loans - Total: 11780.0, Utility - Total: 0.0392501799660383
#
# ############### STEP 19 -> 20 ##################
# White group mean score: 7.91005110732533
# Black group mean score: 17.143336127409952
# Reference bank: White selection rate: 0.5700170357751277
# Reference bank: Black selection rate: 0.21877619446772842
# Market selection rate: 0.54 Interest_rate:[0.1542, 0.1028]
# Loans - White: 11753, Utility - White: 0.030194329958302565
# Loans - Black: 562, Utility - Black: 0.5228464234875441
# Loans - Total: 12315.0, Utility - Total: 0.05267670726755418
#
# ############### STEP 20 -> 21 ##################
# White group mean score: 7.900397501419661
# Black group mean score: 17.681475272422517
# Reference bank: White selection rate: 0.5689948892674617
# Reference bank: Black selection rate: 0.2196144174350377
# Market selection rate: 0.55 Interest_rate:[0.1515, 0.101]
# Loans - White: 12278, Utility - White: 0.038734913666715366
# Loans - Black: 590, Utility - Black: 0.533176423728813
# Loans - Total: 12868.0, Utility - Total: 0.061405141436115245
#
# ############### STEP 21 -> 22 ##################
# White group mean score: 7.770925610448558
# Black group mean score: 18.173512154233094
# Reference bank: White selection rate: 0.565587734241908
# Reference bank: Black selection rate: 0.22129086336965634
# Market selection rate: 0.55 Interest_rate:[0.1515, 0.101]
# Loans - White: 12802, Utility - White: 0.04802132166848393
# Loans - Black: 613, Utility - Black: 0.53797810766721
# Loans - Total: 13415.0, Utility - Total: 0.0704099545285077
#
# ############### STEP 22 -> 23 ##################
# White group mean score: 7.755479840999442
# Black group mean score: 18.755238893545766
# Reference bank: White selection rate: 0.5634298693923907
# Reference bank: Black selection rate: 0.22380553227158423
# Market selection rate: 0.55 Interest_rate:[0.1515, 0.101]
# Loans - White: 13323, Utility - White: 0.05901865270584185
# Loans - Black: 641, Utility - Black: 0.5546932293291724
# Loans - Total: 13964.0, Utility - Total: 0.0817719757948962
#
# ############### STEP 23 -> 24 ##################
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-8db1898983df> in <module>()
#       8
#       9     ### Before ###
# ---> 10     selection_rates, max_util = market.get_selection_rate(banks, groups)
#      11     for bank in banks:
#      12         bank.set_selection_rate(selection_rates[bank.name])
#
# /home/michal/Documents/Schools/TUB/Master thesis/code/market.py in get_selection_rate(self, banks, groups)
#      38     def get_selection_rate(self, banks, groups):
#      39         if self.policy == "Max. utility":
# ---> 40             return self.get_MU_selection_rate(banks, groups)
#      41         elif self.policy == "Dem. parity":
#      42             return self.get_DP_selection_rate(banks, groups)
#
# /home/michal/Documents/Schools/TUB/Master thesis/code/market.py in get_MU_selection_rate(self, banks, groups)
#      59                 for applicant in group.applicants:
#      60                     applicant_score = bank.get_expected_applicant_score(self, applicant.score)
# ---> 61                     utility += bank.get_applicant_evaluation_utility(applicant_score, group)
#      62                     utility_curve[group.name].append(utility)
#      63
#
# /home/michal/Documents/Schools/TUB/Master thesis/code/bank.py in get_applicant_evaluation_utility(self, expected_applicant_score, applicant_group)
#      37
#      38     def get_applicant_evaluation_utility(self, expected_applicant_score, applicant_group):
# ---> 39         return self.utility_default*(1-applicant_group.score_repay_prob[expected_applicant_score]) + (self.utility_repaid+self.score_interest_rates[expected_applicant_score])*applicant_group.score_repay_prob[expected_applicant_score]
#      40
#      41     def get_applicant_utility(self, interest_rate, outcome):
#
# KeyboardInterrupt:

# %% [markdown]
# # Playing with TC, TR, MC, MR and UC

# %%
TC_curve = [0]
TR_curve = [0]
MC_curve = []
MR_curve = []
utility_curve = []
TC=0
TR=0
utility=0

n=0

for k in range(0, groups[n].size):
    expected_applicant_score = banks[0].get_expected_applicant_score(market,groups[n].applicants[k].score)
    utility += banks[0].get_applicant_evaluation_utility(expected_applicant_score, groups[n])
    utility_curve.append(utility*1)
    TC += -banks[0].utility_default*(1-groups[n].score_repay_prob[expected_applicant_score])
    TR += (banks[0].utility_repaid+banks[0].score_interest_rates[expected_applicant_score])*groups[n].score_repay_prob[expected_applicant_score]
    TC_curve.append(TC)
    TR_curve.append(TR)
    MC_curve.append((TC_curve[-1] - TC_curve[-2])*1800)
    MR_curve.append((TR_curve[-1] - TR_curve[-2])*1800)
    
plt.figure(figsize=(8,8))
plt.plot(list(range(0, len(TC_curve))),TC_curve,LineStyle=":",label="Total cost")
plt.plot(list(range(0, len(TR_curve))),TR_curve,LineStyle=":",label="Total revenue")
plt.plot(list(range(0, len(MC_curve))),MC_curve,label="Marginal cost")
plt.plot(list(range(0, len(MR_curve))),MR_curve,label="Marginal revenue")
plt.plot(list(range(0, len(utility_curve))),utility_curve,LineStyle="--",label="Utility curve")
plt.xlabel("Number of loans in white group")
plt.ylabel("Utility/Revenue/Cost")
plt.ylim(0,8000)
plt.xlim(0,9000)
plt.yticks([])
plt.grid("on")
plt.legend()
plt.show

print(utility_curve.index(max(utility_curve)))
i =utility_curve.index(max(utility_curve))
print(MR_curve[i],MR_curve[i+1])
print(MC_curve[i],MC_curve[i+1])
# Out:
# 4946
# 1581.0606463677686 1572.2583651366222
# 1569.5423999999662 1601.3376000000108

# %% [markdown]
# # Perfect competition market

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

fig = plt.figure(figsize=[10,10])
ax = fig.gca(projection='3d')

# Make data.
X = np.arange(0, 1, 0.01)
Y = np.arange(300, 850, 1)
X, Y = np.meshgrid(X, Y)
Z = 5-X*5 + 5-((Y-300)/550)*4 

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(0, 10)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
ax.set_xlabel(r'Market selection rate [$\beta$]')
ax.set_ylabel('Score [x]')
ax.set_zlabel('Interest rate [i%]')
ax.view_init(elev=10., azim=-35)
ax.xaxis.labelpad = 18
ax.yaxis.labelpad = 18
ax.zaxis.labelpad = 18


# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
x1 = [1193, 1193]
x2 = [8805, 8805]
x3 = [9998, 9998]
y = [0, 0.3]

fig = plt.figure(figsize=[7,7])
plt.plot(x1, y, color="black", label="Black group demand")
plt.plot(x2, y, color="grey", label="White group demand" )
plt.plot(x3, y, color="red", label="Total demand")
plt.xlim(0,11000)
plt.title("Market demand")
plt.xlabel("Applicants")
plt.ylabel("Interest rate")
plt.legend()
plt.grid()

plt.savefig("../demand.png")

# %%
x = np.arange(0, 1.001, 0.001)
print(x)
repay = 75
default = -150

y = x*repay + (1-x)*default
print(y)

fig = plt.figure(figsize=[7,7])
plt.plot(x, y, color="black", label="Black group demand")

#plt.xlim(0,11000)
plt.title("Applicant expected score change bae")
plt.xlabel("Repay probability")
plt.ylabel("Expected score change")
plt.legend()
plt.grid()

plt.savefig("../score_change.png")
# Out:
# [0.    0.001 0.002 ... 0.998 0.999 1.   ]
# [-150.    -149.775 -149.55  ...   74.55    74.775   75.   ]

# %%
x = np.arange(0, 1.001, 0.001)
for s in range(300, 851):
    
print(x)
repay = 75
default = -150

y = x*repay + (1-x)*default
print(y)

fig = plt.figure(figsize=[7,7])
plt.plot(x, y, color="black", label="Black group demand")

#plt.xlim(0,11000)
plt.title("Applicant expected score change bae")
plt.xlabel("Repay probability")
plt.ylabel("Expected score change")
plt.legend()
plt.grid()

plt.savefig("../white_score_change.png")
